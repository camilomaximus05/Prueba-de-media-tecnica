# %% [markdown]
# <a href="https://colab.research.google.com/github/camilomaximus05/Prueba-de-media-tecnica/blob/master/Clase16ago2023_pandas_ipnyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ventas = pd.read_csv('/content/ventas.csv')

# %%
ventas.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 0  1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2  1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
#
#    Unidades Ganancia
# 0         6    18,00
# 1         8     3,84
# 2         3     6,30
# 3         9    14,40
# 4        14     6,72

# %%
ventas.head(2)
# Out:
#       Fecha          Vendedor Región          Artículo    Categoría  Unidades  \
# 0  1/1/2016      Steve Ashton  Norte  Medias Femeninas   Vestimenta         6
# 1  1/1/2016  Trevor Snodgrass  Oeste         Chocolate  Comestibles         8
#
#   Ganancia
# 0    18,00
# 1     3,84

# %%
 ventas.tail()
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades Ganancia
# 455         6    16,50
# 456        11   115,50
# 457         4     6,40
# 458         8     6,80
# 459         7     2,10

# %%
ventas.tail(2)
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 458  31/1/2016        Dustin Gee  Norte  Escobillón        Hogar         8
# 459  31/1/2016  Trevor Snodgrass    Sur   Pepinillo  Comestibles         7
#
#     Ganancia
# 458     6,80
# 459     2,10

# %%
ventas.shape[0]
# Out:
# 460

# %%
ventas.shape[1]
# Out:
# 7

# %%
ventas.Vendedor
# Out:
# 0          Steve Ashton
# 1      Trevor Snodgrass
# 2            Sarah Bond
# 3       Desmond Delaney
# 4       Desmond Delaney
#              ...
# 455          Sarah Bond
# 456          Dustin Gee
# 457          Dustin Gee
# 458          Dustin Gee
# 459    Trevor Snodgrass
# Name: Vendedor, Length: 460, dtype: object

# %%
ventas.Artículo
# Out:
# 0       Medias Femeninas
# 1              Chocolate
# 2                 Gorras
# 3      Sánguche de Queso
# 4              Chocolate
#              ...
# 455              Bufanda
# 456            Sandalias
# 457    Sánguche de Queso
# 458           Escobillón
# 459            Pepinillo
# Name: Artículo, Length: 460, dtype: object

# %%
ventas.Región
# Out:
# 0      Norte
# 1      Oeste
# 2        Sur
# 3        Sur
# 4       Este
#        ...
# 455      Sur
# 456     Este
# 457     Este
# 458    Norte
# 459      Sur
# Name: Región, Length: 460, dtype: object

# %%
ventas.Vendedor.value_counts().plot.pie()
# Out:
# <Axes: ylabel='Vendedor'>

# %%
from pickle import TRUE
ventas.Vendedor.value_counts(ascending=True, dropna=True )
# Out:
# Boris Stanford      69
# Dustin Gee          70
# Trevor Snodgrass    75
# Desmond Delaney     76
# Steve Ashton        84
# Sarah Bond          86
# Name: Vendedor, dtype: int64

# %%
ventas.Artículo.value_counts(ascending=True, dropna=True )
# Out:
# Trapo Piso           13
# Cerveza              17
# Caramelos            17
# Bombilla             18
# Limpiavidrios        18
# Soda                 19
# Sandalias            19
# Shorts               19
# Medias Femeninas     20
# Gorras               21
# Calcetines           23
# Pepinillo            24
# Lejía                24
# Sudadera             24
# Detergente           24
# Sánguche de Queso    25
# Chocolate            25
# Escobillón           25
# Pan                  26
# Bufanda              28
# Escoba               31
# Name: Artículo, dtype: int64

# %%
ventas.Artículo.value_counts(ascending=True, dropna=True ).plot.pie()
# Out:
# <Axes: ylabel='Artículo'>

# %%
ventas.sort_values(["Vendedor", "Ganancia"])
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 93    6/1/2016    Boris Stanford  Norte   Chocolate  Comestibles         2
# 450  31/1/2016    Boris Stanford   Este   Chocolate  Comestibles         3
# 259  18/1/2016    Boris Stanford    Sur   Pepinillo  Comestibles         5
# 25    2/1/2016    Boris Stanford   Este         Pan  Comestibles         4
# 64    5/1/2016    Boris Stanford    Sur         Pan  Comestibles         4
# ..         ...               ...    ...         ...          ...       ...
# 231  15/1/2016  Trevor Snodgrass   Este      Gorras   Vestimenta         4
# 314  21/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 328  22/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 69    5/1/2016  Trevor Snodgrass  Norte  Calcetines   Vestimenta         4
# 238  16/1/2016  Trevor Snodgrass    Sur      Shorts   Vestimenta         2
#
#     Ganancia
# 93      0,96
# 450     1,44
# 259     1,50
# ...

# %%
ventas.sort_values(by=["Vendedor", "Ganancia"],)
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 93    6/1/2016    Boris Stanford  Norte   Chocolate  Comestibles         2
# 450  31/1/2016    Boris Stanford   Este   Chocolate  Comestibles         3
# 259  18/1/2016    Boris Stanford    Sur   Pepinillo  Comestibles         5
# 25    2/1/2016    Boris Stanford   Este         Pan  Comestibles         4
# 64    5/1/2016    Boris Stanford    Sur         Pan  Comestibles         4
# ..         ...               ...    ...         ...          ...       ...
# 231  15/1/2016  Trevor Snodgrass   Este      Gorras   Vestimenta         4
# 314  21/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 328  22/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 69    5/1/2016  Trevor Snodgrass  Norte  Calcetines   Vestimenta         4
# 238  16/1/2016  Trevor Snodgrass    Sur      Shorts   Vestimenta         2
#
#     Ganancia
# 93      0,96
# 450     1,44
# 259     1,50
# ...

# %%
ventas[(ventas.Vendedor == "Boris Stanford")]
# Out:
#          Fecha        Vendedor Región           Artículo    Categoría  \
# 6     1/1/2016  Boris Stanford  Norte          Pepinillo  Comestibles
# 11    1/1/2016  Boris Stanford  Oeste         Calcetines   Vestimenta
# 14    2/1/2016  Boris Stanford  Norte  Sánguche de Queso  Comestibles
# 20    2/1/2016  Boris Stanford   Este         Calcetines   Vestimenta
# 21    2/1/2016  Boris Stanford  Oeste            Bufanda   Vestimenta
# ..         ...             ...    ...                ...          ...
# 421  29/1/2016  Boris Stanford   Este  Sánguche de Queso  Comestibles
# 425  29/1/2016  Boris Stanford   Este         Escobillón        Hogar
# 433  30/1/2016  Boris Stanford  Norte               Soda  Comestibles
# 449  31/1/2016  Boris Stanford   Este           Sudadera   Vestimenta
# 450  31/1/2016  Boris Stanford   Este          Chocolate  Comestibles
#
#      Unidades Ganancia
# 6          14     4,20
# 11          7    15,75
# 14          8    12,80
# 20         12    27,00
# ...

# %%
ventas[(ventas.Vendedor == "Boris Stanford") & (ventas.Artículo == "Pepinillo" )].loc[:260, ["Región", "Artículo", "Ganancia"]]
# Out:
#     Región   Artículo Ganancia
# 6    Norte  Pepinillo     4,20
# 259    Sur  Pepinillo     1,50

# %%
def ventasUsuario (usuario, articulo, caracteristicas):
  return ventas[ (ventas.Vendedor =="Boris Stanford") & (ventas.Artículo == "Pepinillo")].loc[:260, ["Región", "Artículo", "Ganancia"]]

  ventasUsuario( "Boris Stanford", "Pepinillo", ["Región", "Artículo", "Ganancia"]).value_counts(asecending=True , dropna=True).plot.pie()
